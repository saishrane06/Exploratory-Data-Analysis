# %% [markdown]
# <a href="https://colab.research.google.com/github/saishrane06/Exploratory-Data-Analysis/blob/main/Credit_Score_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download parisrohan/credit-score-classification
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# ...
#  53% 5.00M/9.51M [00:00<00:00, 50.8MB/s]
# 100% 9.51M/9.51M [00:00<00:00, 85.1MB/s]

# %%
! unzip credit-score-classification.zip
# Out:
# Archive:  credit-score-classification.zip
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
credit_score_df = pd.read_csv("train.csv")
credit_score_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# ...

# %%
credit_score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
credit_score_df.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           84998.000000      100000.000000     100000.00000
# mean             4194.170850          17.091280         22.47443
# std              3183.686167         117.404834        129.05741
# min               303.645417          -1.000000          0.00000
# 25%              1625.568229           3.000000          4.00000
# 50%              3093.745000           6.000000          5.00000
# 75%              5957.448333           7.000000          7.00000
# max             15204.633333        1798.000000       1499.00000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count  100000.000000        100000.000000          98035.000000
# mean       72.466040            21.068780             27.754251
# std       466.422621            14.860104            193.177339
# min         1.000000            -5.000000              0.000000
# ...

# %%
credit_score_df.shape
# Out:
# (100000, 28)

# %%
credit_score_df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
for i in credit_score_df.columns:
  if credit_score_df[i].dtype == "object":
    print("\n")
    print(i,end="\n")
    print(credit_score_df[i],end="\n")
    print("Unique values of {} is \n".format(i),credit_score_df[i].unique())
    #print(credit_score_df[i].unique())
# Out:
# ID
# 0         0x1602
# 1         0x1603
# 2         0x1604
# 3         0x1605
# 4         0x1606
#           ...
# 99995    0x25fe9
# 99996    0x25fea
# 99997    0x25feb
# 99998    0x25fec
# 99999    0x25fed
# Name: ID, Length: 100000, dtype: object
# Unique values of ID is
#  ['0x1602' '0x1603' '0x1604' ... '0x25feb' '0x25fec' '0x25fed']
#
#
# Customer_ID
# 0         CUS_0xd40
# 1         CUS_0xd40
# 2         CUS_0xd40
# 3         CUS_0xd40
# 4         CUS_0xd40
#             ...
# 99995    CUS_0x942c
# 99996    CUS_0x942c
# 99997    CUS_0x942c
# 99998    CUS_0x942c
# 99999    CUS_0x942c
# Name: Customer_ID, Length: 100000, dtype: object
# Unique values of Customer_ID is
#  ['CUS_0xd40' 'CUS_0x21b1' 'CUS_0x2dbc' ... 'CUS_0xaf61' 'CUS_0x8600'
#  'CUS_0x942c']
#
#
# Month
# 0         January
# 1        February
# 2           March
# 3           April
# 4             May
#            ...
# 99995       April
# 99996         May
# 99997        June
# 99998        July
# ...

# %%
for i in credit_score_df.columns:
  if credit_score_df[i].isna().any():
    print(i," ",credit_score_df[i].isna().sum())
# Out:
# Name   9985
# Monthly_Inhand_Salary   15002
# Type_of_Loan   11408
# Num_of_Delayed_Payment   7002
# Num_Credit_Inquiries   1965
# Credit_History_Age   9030
# Amount_invested_monthly   4479
# Monthly_Balance   1200

# %% [markdown]
# ### **Data Cleaning**

# %% [markdown]
# **Handling Null Values**

# %%
credit_score_df = credit_score_df.drop("Name",axis=1)

# %%
#credit_score_df['Monthly_Inhand_Salary'] = credit_score_df['Monthly_Inhand_Salary'].fillna(credit_score_df['Monthly_Inhand_Salary'].mean())
credit_score_df['Customer_ID'].unique().tolist()
# Out:
# ['CUS_0xd40',
#  'CUS_0x21b1',
#  'CUS_0x2dbc',
#  'CUS_0xb891',
#  'CUS_0x1cdb',
#  'CUS_0x95ee',
#  'CUS_0x284a',
#  'CUS_0x5407',
#  'CUS_0x4157',
#  'CUS_0xba08',
#  'CUS_0xa66b',
#  'CUS_0xc0ab',
#  'CUS_0x3e45',
#  'CUS_0x6c66',
#  'CUS_0xff4',
#  'CUS_0x33d2',
#  'CUS_0x6070',
#  'CUS_0xfdb',
#  'CUS_0x3553',
#  'CUS_0x4100',
#  'CUS_0x132f',
#  'CUS_0xa16e',
#  'CUS_0xac86',
#  'CUS_0x5b48',
#  'CUS_0xa5f9',
#  'CUS_0x4d43',
#  'CUS_0xb95f',
#  'CUS_0x3edc',
#  'CUS_0xbffe',
#  'CUS_0xb681',
#  'CUS_0x9a71',
#  'CUS_0x6048',
#  'CUS_0x95b5',
#  'CUS_0x4004',
#  'CUS_0xb101',
#  'CUS_0x9b94',
#  'CUS_0x4080',
#  'CUS_0x706a',
#  'CUS_0x42ac',
#  'CUS_0x571f',
#  'CUS_0xb5ff',
#  'CUS_0x6a1b',
#  'CUS_0x9bc1',
#  'CUS_0xc65',
#  'CUS_0xaedb',
#  'CUS_0x8e9b',
#  'CUS_0x609d',
#  'CUS_0x75c6',
#  'CUS_0x9b3c',
#  'CUS_0x22a3',
#  'CUS_0xb14',
#  'CUS_0xb986',
#  'CUS_0xbe1b',
#  'CUS_0x9ce6',
#  'CUS_0x6ffb',
#  'CUS_0x4315',
#  'CUS_0x3f5b',
#  'CUS_0x9d78',
#  'CUS_0x47db',
# ...

# %%
a = []
b=[]
sum = 0
for i in credit_score_df['Customer_ID'].unique().tolist():
  a.append(i)
  #print(i)
  if i == a[sum]:
    print(i)
    #print(credit_score_df.head())
    #credit_score_df['Monthly_Inhand_Salary'] = credit_score_df['Monthly_Inhand_Salary'].fillna(credit_score_df['Monthly_Inhand_Salary'][sum])
  sum = sum + 1
credit_score_df.head(20)
# Out:
# Streaming output truncated to the last 5000 lines.
# CUS_0xa505
# CUS_0xc06e
# CUS_0x57c2
# CUS_0x8c88
# CUS_0x74e9
# CUS_0x6f4c
# CUS_0x14d1
# CUS_0x76b8
# CUS_0x63a6
# CUS_0x9eb9
# CUS_0x5ee0
# CUS_0xc59e
# CUS_0x5c68
# CUS_0xa974
# CUS_0x9c85
# CUS_0x1011
# CUS_0xb381
# CUS_0x148b
# CUS_0xc067
# CUS_0x991d
# CUS_0xbb43
# CUS_0xbccf
# CUS_0x40d
# CUS_0x3bd2
# CUS_0x3a6c
# CUS_0x3053
# CUS_0x39cf
# CUS_0x5c59
# CUS_0x4f65
# CUS_0x9017
# CUS_0x5f49
# CUS_0x5235
# CUS_0x84a9
# CUS_0x9b9e
# CUS_0x4148
# CUS_0x348a
# CUS_0x6f22
# CUS_0x5bc7
# CUS_0x16d0
# CUS_0x8bce
# CUS_0x8201
# CUS_0x5f0f
# CUS_0x102e
# CUS_0x52d5
# CUS_0x829a
# CUS_0x9ece
# CUS_0x6148
# CUS_0x40d1
# CUS_0x6b1c
# CUS_0x885d
# CUS_0x1aee
# CUS_0x4192
# CUS_0x40f8
# CUS_0xa7db
# CUS_0x6f86
# CUS_0xbbbb
# CUS_0x51e6
# CUS_0x5f25
# CUS_0x74bf
# CUS_0x9cc3
# CUS_0xab37
# CUS_0x4778
# CUS_0x53f0
# CUS_0x5f83
# CUS_0x836e
# CUS_0x2abc
# CUS_0xc180
# CUS_0x9513
# CUS_0x44c3
# CUS_0x3fce
# CUS_0x8d33
# CUS_0x2adf
# ...
